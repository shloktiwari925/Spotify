# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import random

# %%
sp = pd.read_excel(r'C:\Users\shukl\OneDrive\Desktop\Practice dataset\spotify.xlsx')
sp
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
sp.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
sp.shape
# Out:
# (50, 14)

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
sp = sp.drop('Unnamed: 0', axis=1)
sp
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
sp.shape
# Out:
# (50, 13)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(sp.corr(), annot=True)
plt.show()
# Out:
# C:\Users\shukl\AppData\Local\Temp\ipykernel_2180\1659795999.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sp.corr(), annot=True)

# %%
sp.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# ...

# %%
value = sp['Genre'].value_counts()

# %%
sp1 = sp[sp['Genre'].isin(value.index[value > 1])]
sp1.shape
# Out:
# (42, 13)

# %%
sp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track.Name        42 non-null     object
#  1   Artist.Name       42 non-null     object
#  2   Genre             42 non-null     object
#  3   Beats.Per.Minute  42 non-null     int64
#  4   Energy            42 non-null     int64
#  5   Danceability      42 non-null     int64
#  6   Loudness..dB..    42 non-null     int64
#  7   Liveness          42 non-null     int64
#  8   Valence.          42 non-null     int64
#  9   Length.           42 non-null     int64
#  10  Acousticness..    42 non-null     int64
#  11  Speechiness.      42 non-null     int64
#  12  Popularity        42 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 4.6+ KB

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Artist.Name', y='Beats.Per.Minute', data = sp1)
plt.xticks(rotation=90)
plt.title('Singer with their Rate of Beat Drop')
plt.grid(ls=':', c='y')
plt.xlabel('Name of Singers')
plt.ylabel('Beat Drop Rate')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Genre', y='Beats.Per.Minute', data = sp1)
plt.xticks(rotation=90)
plt.title('Genre with Rate of Beat Drop')
plt.grid(ls=':', c='k')
plt.xlabel('Name of Genre')
plt.ylabel('Beat Drop Rate')
plt.show()

# %%
plt.figure(figsize=(13,7))
sp1['Genre'].value_counts().plot(kind='pie',autopct='%0.2f%%')
plt.title('Genre count')
plt.ylabel('Types of Genre')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Artist.Name',y='Energy',data=sp1)
plt.xticks(rotation=90)
plt.title('Energy level of Singers')
plt.xlabel('Singers')
plt.grid(ls=':',c='k')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Artist.Name', y='Danceability', data=sp1, hue='Genre')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation = 90)
plt.title('Danceability of songs according to singers and genre')
plt.xlabel('Singers')
plt.grid(ls=':', c='y')
plt.show()

# %%
sp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track.Name        42 non-null     object
#  1   Artist.Name       42 non-null     object
#  2   Genre             42 non-null     object
#  3   Beats.Per.Minute  42 non-null     int64
#  4   Energy            42 non-null     int64
#  5   Danceability      42 non-null     int64
#  6   Loudness..dB..    42 non-null     int64
#  7   Liveness          42 non-null     int64
#  8   Valence.          42 non-null     int64
#  9   Length.           42 non-null     int64
#  10  Acousticness..    42 non-null     int64
#  11  Speechiness.      42 non-null     int64
#  12  Popularity        42 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 4.6+ KB

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Artist.Name', y='Popularity', data=sp1, hue='Genre')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation = 90)
plt.title('Popularity of singers')
plt.xlabel('Singers')
plt.grid(ls=':', c='y')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = 'Liveness', y = 'Speechiness.' ,data =sp1,c='r', hue='Genre')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.xlabel('Liveness')
plt.ylabel('Speechiness')
plt.title('Liveness vs Speechiness')
plt.grid(ls=':',c='k')
plt.show()

# %%
sp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track.Name        42 non-null     object
#  1   Artist.Name       42 non-null     object
#  2   Genre             42 non-null     object
#  3   Beats.Per.Minute  42 non-null     int64
#  4   Energy            42 non-null     int64
#  5   Danceability      42 non-null     int64
#  6   Loudness..dB..    42 non-null     int64
#  7   Liveness          42 non-null     int64
#  8   Valence.          42 non-null     int64
#  9   Length.           42 non-null     int64
#  10  Acousticness..    42 non-null     int64
#  11  Speechiness.      42 non-null     int64
#  12  Popularity        42 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 4.6+ KB

# %%
plt.figure(figsize=(10,4))
sns.lineplot(x= 'Speechiness.' , y='Beats.Per.Minute', data=sp1, c='r')
plt.title('Speechiness according to beat drop')
plt.grid(ls=':', c='k')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x = 'Energy', y = 'Loudness..dB..' ,data =sp1,c='y')
plt.xlabel('Energy')
plt.ylabel('Loudness..dB..')
plt.title('Loudness..dB.. vs Energy')
plt.grid(ls=':',c='k')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Energy',y='Valence.',data=sp1)
plt.xticks(rotation=90)
plt.title('Energy level of Singers')
plt.xlabel('Singers')
plt.grid(ls=':',c='k')
plt.show()
